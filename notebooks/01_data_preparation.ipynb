# %% [markdown]
# # Data Preparation
#
# This notebook corresponds to one stage of the reproducibility workflow for the M5 supply-chain demand forecasting study.

# %%
import numpy as np
import pandas as pd
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
ROOT
